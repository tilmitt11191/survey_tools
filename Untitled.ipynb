# %%
import py2cytoscape.cytoscapejs as renderer

view = g_cy.get_first_view()
# style_for_widget = cy.style.get(my_yeast_style.get_name(), data_format='cytoscapejs')
renderer.render(view, 'Directed', background='radial-gradient(#FFFFFF 15%, #DDDDDD 105%)')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8f8894ac5916> in <module>()
#       1 import py2cytoscape.cytoscapejs as renderer
#       2
# ----> 3 view = g_cy.get_first_view()
#       4 # style_for_widget = cy.style.get(my_yeast_style.get_name(), data_format='cytoscapejs')
#       5 renderer.render(view, 'Directed', background='radial-gradient(#FFFFFF 15%, #DDDDDD 105%)')
#
# NameError: name 'g_cy' is not defined

# %%
from py2cytoscape.data.cyrest_client import CyRestClient

cy = CyRestClient(ip='127.0.0.1', port=1234)

# 現在のセッションのクリア
cy.session.delete()

# %%
import networkx as nx
g = nx.scale_free_graph(500)

# %%
deg = nx.degree(g)
btw = nx.betweenness_centrality(g)

nx.set_node_attributes(g, 'degree', deg)
nx.set_node_attributes(g, 'betweenness', btw)

# %%
g_cy = cy.network.create_from_networkx(g)

# %%
cy.layout.apply(name='kamada-kawai', network=g_cy)

# %%
directed = cy.style.create('Directed')
cy.style.apply(directed, network=g_cy)

# %%
result = cy.edgebundling.apply(g_cy)

# %%
import py2cytoscape.cytoscapejs as renderer

view = g_cy.get_first_view()
# style_for_widget = cy.style.get(my_yeast_style.get_name(), data_format='cytoscapejs')
renderer.render(view, 'Directed', background='radial-gradient(#FFFFFF 15%, #DDDDDD 105%)')
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset=utf-8 />
#     <style type="text/css">
#       body {
#           font: 14px helvetica neue, helvetica, arial, sans-serif;
#       }
#
#       #cyd5bd488b-3eda-4c47-8d5d-5137bd535331 {
#         height: 700px;
#         width: 1098px;
#         position: absolute;
#         left: 4px;
#         top: 5px;
#         background: radial-gradient(#FFFFFF 15%, #DDDDDD 105%);
#       }
#     </style>
#
#     <script>
#     (function() {
#       function render() {
#         $('#cyd5bd488b-3eda-4c47-8d5d-5137bd535331').cytoscape({
#             elements: {
#                 nodes: [{"position": {"y": -643.7059478276337, "x": -1043.7349721819016}, "selected": false, "data": {"id_original": "499", "name": "499", "degree": 1.0, "SUID": 4650, "selected": false, "betweenness": 0.0, "shared_name": "499", "id": "4650"}}, {"position": {"y": -97.53071779407628, "x": -1417.5619781635803}, "selected": false, "data": {"id_original": "498", "name": "498", "degree": 1.0, "SUID": 4649, "selected": false, "betweenness": 0.0, "shared_name": "498", "id": "4649"}}, {"position": {"y": 1053.718243154009, "x": 399.76658168371}, "selected": false, "data": {"id_original": "497", "name": "497", "degree": 1.0, "SUID": 4648, "selected": false, "betweenness": 0.0, "shared_name": "497", "id": "4648"}}, {"position": {"y": -1318.053864267336, "x": -330.4559217543108}, "selected": false, "data": {"id_original": "496", "name": "496", "degree": 1.0, "SUID": 4647, "selected": false, "betweenness": 0.0, "shared_name": "496", "id": "4647"}}, {"position": {"y": 465.0342594495155, "x": 909.7823526843488}, "selected": false, "data": {"id_original": "495", "name": "495", "degree": 1.0, "SUID": 4646, "selected": false, "betweenness": 0.0, "shared_name": "495", "id": "4646"}}, {"position": {"y": 938.5431114261878, "x": 190.3383785091239}, "selected": false, "data": {"id_original": "494", "name": "494", "degree": 1.0, "SUID": 4645, "selected": false, "betweenness": 0.0, "shared_name": "494", "id": "4645"}}, {"position": {"y": -603.8754401813198, "x": -1090.128530169987}, "selected": false, "data": {"id_original": "493", "name": "493", "degree": 1.0, "SUID": 4644, "selected": false, "betweenness": 0.0, "shared_name": "493", "id": "4644"}}, {"position": {"y": -601.4292940005721, "x": 1157.1620009438695}, "selected": false, "data": {"id_original": "492", "name": "492", "degree": 1.0, "SUID": 4643, "selected": false, "betweenness": 0.0, "shared_name": "492", "id": "4643"}}, {"position": {"y": -281.4615683952293, "x": -1385.745956728763}, "selected": false, "data": {"id_original": "491", "name": "491", "degree": 1.0, "SUID": 4642, "selected": false, "betweenness": 0.0, "shared_name": "491", "id": "4642"}}, {"position": {"y": 410.1579600124328, "x": -1036.6338009110084}, "selected": false, "data": {"id_original": "490", "name": "490", "degree": 1.0, "SUID": 4641, "selected": false, "betweenness": 0.0, "shared_name": "490", "id": "4641"}}, {"position": {"y": 1105.7162690303771, "x": 436.49482641487634}, "selected": false, "data": {"id_original": "489", "name": "489", "degree": 1.0, "SUID": 4640, "selected": false, "betweenness": 0.0, "shared_name": "489", "id": "4640"}}, {"position": {"y": 566.4180751746494, "x": 924.8168444285832}, "selected": false, "data": {"id_original": "488", "name": "488", "degree": 1.0, "SUID": 4639, "selected": false, "betweenness": 0.0, "shared_name": "488", "id": "4639"}}, {"position": {"y": -741.4032321031914, "x": -1013.8752077633187}, "selected": false, "data": {"id_original": "487", "name": "487", "degree": 1.0, "SUID": 4638, "selected": false, "betweenness": 0.0, "shared_name": "487", "id": "4638"}}, {"position": {"y": -830.3694451993401, "x": 878.3874525354906}, "selected": false, "data": {"id_original": "486", "name": "486", "degree": 1.0, "SUID": 4637, "selected": false, "betweenness": 0.0, "shared_name": "486", "id": "4637"}}, {"position": {"y": 941.3592306272599, "x": 272.31271796889564}, "selected": false, "data": {"id_original": "485", "name": "485", "degree": 1.0, "SUID": 4636, "selected": false, "betweenness": 0.0, "shared_name": "485", "id": "4636"}}, {"position": {"y": -776.2939860557631, "x": 918.9917393694188}, "selected": false, "data": {"id_original": "484", "name": "484", "degree": 1.0, "SUID": 4635, "selected": false, "betweenness": 0.0, "shared_name": "484", "id": "4635"}}, {"position": {"y": 865.7019314216082, "x": 517.4486284724801}, "selected": false, "data": {"id_original": "483", "name": "483", "degree": 1.0, "SUID": 4634, "selected": false, "betweenness": 0.0, "shared_name": ...

# %%
import py2cytoscape.cytoscapejs as renderer

view = g_cy.get_first_view()
style_for_widget = cy.style.get(my_yeast_style.get_name(), data_format='cytoscapejs')
renderer.render(view, 'Directed', background='radial-gradient(#FFFFFF 15%, #DDDDDD 105%)')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-5504718b007e> in <module>()
#       2
#       3 view = g_cy.get_first_view()
# ----> 4 style_for_widget = cy.style.get(my_yeast_style.get_name(), data_format='cytoscapejs')
#       5 renderer.render(view, 'Directed', background='radial-gradient(#FFFFFF 15%, #DDDDDD 105%)')
#
# NameError: name 'my_yeast_style' is not defined
